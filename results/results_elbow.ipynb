# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from yellowbrick.cluster.elbow import kelbow_visualizer
import matplotlib.cm as cm
# %matplotlib inline

# %%
### Load Results ###
#Class 4 Industrial
dist_tca4 = pd.read_csv('C:/LUMOS/MCK/Output_DFs/TCA4_df.csv')

dist_pland4 = pd.read_csv('C:/LUMOS/MCK/Output_DFs/PLAND4_df.csv')

#Class 14  Potatoes
dist_tca14 = pd.read_csv('C:/LUMOS/MCK/Output_DFs/TCA14_df.csv')

dist_pland14 = pd.read_csv('C:/LUMOS/MCK/Output_DFs/PLAND14_df.csv')


#Class 22 Nature
dist_tca22 = pd.read_csv('E:/thesis_data/Output_DFs/Total Class Area[class 22]_df.csv')

dist_pland22 = pd.read_csv('E:/thesis_data/Output_DFs/PLAND[class 22]_df.csv')

# OQD_22
qd22_df = pd.read_csv('E:/thesis_data/Output_DFs/quantitydifferencecategorical_22_df.csv')
np.fill_diagonal(qd22_df.values, 0)

"""Non categorical metrics"""
# Shannon
dist_shan = pd.read_csv('E:/thesis_data/Output_DFs/shannon_df.csv')
# Simpsons
dist_simp = pd.read_csv('E:/thesis_data/Output_DFs/simp_df.csv')
# Kappa
kappa_df = pd.read_csv('E:/thesis_data/Output_DFs/kappa.csv', index_col= 'Unnamed: 0')
dist_kappa = 1 - kappa_df
# OA
oa_df = pd.read_csv('E:/thesis_data/Output_DFs/overallaccuracy_df.csv')
dist_oa = 1 - oa_df
# OAD
oad_df = pd.read_csv('E:/thesis_data/Output_DFs/overallallocationdifference_df.csv')
np.fill_diagonal(oad_df.values, 0)
# OD
od_df = pd.read_csv('E:/thesis_data/Output_DFs/overalldifference_df.csv')
np.fill_diagonal(od_df.values, 0)
# OQD
oqd_df = pd.read_csv('E:/thesis_data/Output_DFs/overallquantitydifference_df.csv')
np.fill_diagonal(oqd_df.values, 0)

# %%
"""Create the clusters for all metrics """
init_clusters=4
kappaclusters = AgglomerativeClustering(n_clusters=init_clusters, affinity='precomputed', linkage='complete').fit(dist_kappa)
shannonclusters = AgglomerativeClustering(n_clusters=init_clusters, affinity='precomputed', linkage='complete').fit(dist_shan)
simpsonclusters = AgglomerativeClustering(n_clusters=init_clusters, affinity='precomputed', linkage='complete').fit(dist_simp)
oaclusters = AgglomerativeClustering(n_clusters=init_clusters, affinity='precomputed', linkage='complete').fit(dist_oa)
odclusters = AgglomerativeClustering(n_clusters=init_clusters, affinity='precomputed', linkage='complete').fit(od_df)
oadclusters = AgglomerativeClustering(n_clusters=init_clusters, affinity='precomputed', linkage='complete').fit(oad_df)
oqdclusters = AgglomerativeClustering(n_clusters=init_clusters, affinity='precomputed', linkage='complete').fit(oqd_df)
qd22clusters = AgglomerativeClustering(n_clusters=init_clusters, affinity='precomputed', linkage='complete').fit(qd22_df)
tcacluster4 = AgglomerativeClustering(n_clusters=init_clusters, affinity='precomputed', linkage='complete').fit(dist_tca4)
tcacluster14 = AgglomerativeClustering(n_clusters=init_clusters, affinity='precomputed', linkage='complete').fit(dist_tca14)
tcacluster22 = AgglomerativeClustering(n_clusters=init_clusters, affinity='precomputed', linkage='complete').fit(dist_tca22)
plandcluster4 = AgglomerativeClustering(n_clusters=init_clusters, affinity='precomputed', linkage='complete').fit(dist_pland4)
plandcluster14 = AgglomerativeClustering(n_clusters=init_clusters, affinity='precomputed', linkage='complete').fit(dist_pland14)
plandcluster22 = AgglomerativeClustering(n_clusters=init_clusters, affinity='precomputed', linkage='complete').fit(dist_pland22)

# %% [markdown]
# # TCA 4

# %%
fig = plt.figure(figsize=(14, 14))
_ = kelbow_visualizer(tcacluster4, dist_tca4, k=(2,12), timings=False)

# %% [markdown]
# # TCA 14

# %%
fig = plt.figure(figsize=(14, 14))
_ = kelbow_visualizer(tcacluster14, dist_tca14, k=(2,12), timings=False)

# %% [markdown]
# # TCA 22

# %%
fig = plt.figure(figsize=(14, 14))
_ = kelbow_visualizer(tcacluster22, dist_tca22, k=(2,12), timings=False)

# %% [markdown]
# # PLAND 4

# %%
fig = plt.figure(figsize=(14, 14))
_ = kelbow_visualizer(plandcluster4, dist_pland4, k=(2,12), timings=False)

# %% [markdown]
# # PLAND 14

# %%
fig = plt.figure(figsize=(14, 14))
_ = kelbow_visualizer(plandcluster14, dist_pland14, k=(2,12), timings=False)

# %% [markdown]
# # PLAND 22

# %%
fig = plt.figure(figsize=(14, 14))
_ = kelbow_visualizer(plandcluster22, dist_pland22, k=(2,12), timings=False)

# %% [markdown]
# # QD 22

# %%
fig = plt.figure(figsize=(14, 14))
_ = kelbow_visualizer(qd22clusters, qd22_df, k=(2,12), timings=False)

# %% [markdown]
# # Kappa

# %%
fig = plt.figure(figsize=(14, 14))
_ = kelbow_visualizer(kappaclusters, dist_kappa, k=(2,12), timings=False)

# %% [markdown]
# # Overall Accuracy

# %%
fig = plt.figure(figsize=(14, 14))
_ = kelbow_visualizer(oaclusters, dist_oa, k=(2,12), timings=False)

# %% [markdown]
# # Overall Difference

# %%
fig = plt.figure(figsize=(14, 14))
_ = kelbow_visualizer(odclusters, od_df, k=(2,12), timings=False)

# %% [markdown]
# # Overall Allocation Difference

# %%
fig = plt.figure(figsize=(14, 14))
_ = kelbow_visualizer(oadclusters, oad_df, k=(2,12), timings=False)

# %% [markdown]
# # Overall Quantity Difference

# %%
fig = plt.figure(figsize=(14, 14))
_ = kelbow_visualizer(oqdclusters, oqd_df, k=(2,12), timings=False)

# %% [markdown]
# # Simpson's Diversity Index

# %%
fig = plt.figure(figsize=(14, 14))
_ = kelbow_visualizer(simpsonclusters, dist_simp, k=(2,12), timings=False)

# %% [markdown]
# # Shannon's Diversity Index

# %%
fig = plt.figure(figsize=(14, 14))
_ = kelbow_visualizer(shannonclusters, dist_shan, k=(2,12), timings=False)
